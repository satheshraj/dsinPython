# %% [markdown]
# # Number Guessing Game

# %% [markdown]
# ## Asses the guessed number with the secret number

# %%
secret_number = 7
for i in range(1,8):
    print(f"Attempt :{i}")
    guessed_value = int(input("Enter your guess"))
    if guessed_value < 0 or guessed_value > 100:
        print("Please enter guesses between 0 and 100")
    elif guessed_value < secret_number:
        print("Your guessed value is lesser than secret number")
    elif guessed_value > secret_number:
        print("Your guessed value is greater than secret number")
    elif guessed_value == secret_number:
        print(f"Your guessed value {guessed_value} is right. Found in attempt no {i}")
        break
    else:
        print(f"Your guessed value {guessed_value} is wrong")
# Out:
# Attempt :1
# Your guessed value is lesser than secret number
# Attempt :2
# Your guessed value is lesser than secret number
# Attempt :3
# Your guessed value is greater than secret number
# Attempt :4
# Your guessed value is greater than secret number
# Attempt :5
# Your guessed value is greater than secret number
# Attempt :6
# Your guessed value is greater than secret number
# Attempt :7
# Your guessed value 7 is right. Attempt :7
